# %% [markdown]
# # 1 Block

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Set the path to your balanced dataset
balanced_dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Set the image dimensions and other parameters
input_shape = (224, 224, 3)
batch_size = 32
num_classes = 3
epochs = 20

# Create the data generator for training and validation without data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test generator
test_generator = test_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Calculate the class weights to handle data imbalance
class_weights_balanced = dict(zip(range(num_classes), ((len(train_generator_balanced.classes) / (num_classes * np.bincount(train_generator_balanced.classes))).tolist())))

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc = model.evaluate(test_generator, verbose=0)
        test_loss.append(loss)
        test_accuracy.append(acc)
        print(f'Test loss: {loss:.4f} - Test accuracy: {acc:.4f}')

# Train the model with the custom callback
history = model.fit(train_generator_balanced, 
                    epochs=epochs, 
                    validation_data=validation_generator_balanced, 
                    class_weight=class_weights_balanced,
                    callbacks=[TestCallback()])

# Final evaluation on the test set
loss, accuracy = model.evaluate(test_generator)
print('Final Test Loss:', loss)
print(f'Final Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Found 1106 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 1578 images belonging to 3 classes.
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.3664 - loss: 12.4762Test loss: 0.8762 - Test accuracy: 0.7383
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 639ms/step - accuracy: 0.3679 - loss: 12.2995 - val_accuracy: 0.6377 - val_loss: 0.9796
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7961 - loss: 0.8400Test loss: 0.6209 - Test accuracy: 0.8093
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 606ms/step - accuracy: 0.7956 - loss: 0.8392 - val_accuracy: 0.6038 - val_loss: 0.9016
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8862 - loss: 0.5024Test loss: 0.4458 - Test accuracy: 0.8580
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 602ms/step - accuracy: 0.8862 - loss: 0.5011 - val_accuracy: 0.5996 - val_loss: 1.0328
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9600 - loss: 0.1548Test loss: 0.4496 - Test accuracy: 0.8745
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 599ms/step - accuracy: 0.9600 - loss: 0.1543 - val_accuracy: 0.6250 - val_loss: 1.3451
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9947 - loss: 0.0331Test loss: 0.4154 - Test accuracy: 0.8929
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 603ms/step - accuracy: 0.9947 - loss: 0.0331 - val_accuracy: 0.6441 - val_loss: 1.3707
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0049Test loss: 0.4759 - Test accuracy: 0.8954
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 607ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.6504 - val_loss: 1.5866
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 1.0000 - loss: 0.0015Test loss: 0.4934 - Test accuracy: 0.8929
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 626ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6419 - val_loss: 1.6462
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 1.0000 - loss: 0.0024Test loss: 0.5003 - Test accuracy: 0.8967
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 604ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6547 - val_loss: 1.6697
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 1.0000 - loss: 0.0014Test loss: 0.5107 - Test accuracy: 0.8935
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 610ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6441 - val_loss: 1.7061
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 3.4113e-04Test loss: 0.5591 - Test accuracy: 0.8885
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 606ms/step - accuracy: 1.0000 - loss: 3.4152e-04 - val_accuracy: 0.6271 - val_loss: 1.8684
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 2.6982e-04Test loss: 0.5649 - Test accuracy: 0.8891
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 598ms/step - accuracy: 1.0000 - loss: 2.6946e-04 - val_accuracy: 0.6292 - val_loss: 1.8881
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 1.9605e-04Test loss: 0.5748 - Test accuracy: 0.8897
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 589ms/step - accuracy: 1.0000 - loss: 1.9606e-04 - val_accuracy: 0.6314 - val_loss: 1.9212
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 1.6776e-04Test loss: 0.5792 - Test accuracy: 0.8891
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 625ms/step - accuracy: 1.0000 - loss: 1.6750e-04 - val_accuracy: 0.6292 - val_loss: 1.9360
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 1.3952e-04Test loss: 0.5950 - Test accuracy: 0.8891
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 603ms/step - accuracy: 1.0000 - loss: 1.3937e-04 - val_accuracy: 0.6292 - val_loss: 1.9891
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 1.1667e-04Test loss: 0.5931 - Test accuracy: 0.8891
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 596ms/step - accuracy: 1.0000 - loss: 1.1664e-04 - val_accuracy: 0.6292 - val_loss: 1.9827
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 9.4758e-05Test loss: 0.6068 - Test accuracy: 0.8885
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 600ms/step - accuracy: 1.0000 - loss: 9.4841e-05 - val_accuracy: 0.6271 - val_loss: 2.0286
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 8.4953e-05Test loss: 0.6074 - Test accuracy: 0.8891
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 601ms/step - accuracy: 1.0000 - loss: 8.4992e-05 - val_accuracy: 0.6292 - val_loss: 2.0305
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 7.8272e-05Test loss: 0.6167 - Test accuracy: 0.8885
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 600ms/step - accuracy: 1.0000 - loss: 7.8210e-05 - val_accuracy: 0.6271 - val_loss: 2.0616
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 1.0000 - loss: 7.2481e-05Test loss: 0.6256 - Test accuracy: 0.8878
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 612ms/step - accuracy: 1.0000 - loss: 7.2366e-05 - val_accuracy: 0.6250 - val_loss: 2.0915
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 6.3336e-05Test loss: 0.6275 - Test accuracy: 0.8885
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 595ms/step - accuracy: 1.0000 - loss: 6.3267e-05 - val_accuracy: 0.6271 - val_loss: 2.0978
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 215ms/step - accuracy: 0.8557 - loss: 0.6776
# Final Test Loss: 0.6275199055671692
# Final Test Accuracy: 88.85%

# %% [markdown]
# # 2 Block

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Set the path to your balanced dataset
balanced_dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Set the image dimensions and other parameters
input_shape = (224, 224, 3)
batch_size = 32
num_classes = 3
epochs = 20

# Create the data generator for training and validation without data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test generator
test_generator = test_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Calculate the class weights to handle data imbalance
class_weights_balanced = dict(zip(range(num_classes), ((len(train_generator_balanced.classes) / (num_classes * np.bincount(train_generator_balanced.classes))).tolist())))

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc = model.evaluate(test_generator, verbose=0)
        test_loss.append(loss)
        test_accuracy.append(acc)
        print(f'Test loss: {loss:.4f} - Test accuracy: {acc:.4f}')

# Train the model with the custom callback
history = model.fit(train_generator_balanced, 
                    epochs=epochs, 
                    validation_data=validation_generator_balanced, 
                    class_weight=class_weights_balanced,
                    callbacks=[TestCallback()])

# Final evaluation on the test set
loss, accuracy = model.evaluate(test_generator)
print('Final Test Loss:', loss)
print(f'Final Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Found 1106 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 1578 images belonging to 3 classes.
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.3805 - loss: 5.2514Test loss: 0.9419 - Test accuracy: 0.5900
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 33s 773ms/step - accuracy: 0.3809 - loss: 5.1796 - val_accuracy: 0.5530 - val_loss: 0.9771
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6514 - loss: 0.8017Test loss: 0.6090 - Test accuracy: 0.7687
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 600ms/step - accuracy: 0.6519 - loss: 0.8005 - val_accuracy: 0.6314 - val_loss: 0.8787
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8450 - loss: 0.4341Test loss: 0.4630 - Test accuracy: 0.8454
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 595ms/step - accuracy: 0.8450 - loss: 0.4336 - val_accuracy: 0.6653 - val_loss: 1.0414
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9427 - loss: 0.1901Test loss: 0.4362 - Test accuracy: 0.8821
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 595ms/step - accuracy: 0.9428 - loss: 0.1892 - val_accuracy: 0.6547 - val_loss: 1.2992
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9771 - loss: 0.0604Test loss: 0.4530 - Test accuracy: 0.8948
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 599ms/step - accuracy: 0.9772 - loss: 0.0601 - val_accuracy: 0.6653 - val_loss: 1.4180
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9984 - loss: 0.0200Test loss: 0.5145 - Test accuracy: 0.9100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 606ms/step - accuracy: 0.9983 - loss: 0.0199 - val_accuracy: 0.7055 - val_loss: 1.6943
# Epoch 7/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9987 - loss: 0.0071Test loss: 0.5402 - Test accuracy: 0.9043
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 595ms/step - accuracy: 0.9987 - loss: 0.0071 - val_accuracy: 0.6843 - val_loss: 1.7921
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9965 - loss: 0.0095Test loss: 0.6679 - Test accuracy: 0.9081
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 603ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.6970 - val_loss: 2.2160
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9975 - loss: 0.0081Test loss: 0.5976 - Test accuracy: 0.9081
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 595ms/step - accuracy: 0.9975 - loss: 0.0081 - val_accuracy: 0.6928 - val_loss: 1.9898
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9995 - loss: 0.0030Test loss: 0.5801 - Test accuracy: 0.9068
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 588ms/step - accuracy: 0.9995 - loss: 0.0030 - val_accuracy: 0.6907 - val_loss: 1.9272
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9998 - loss: 0.0015Test loss: 0.6311 - Test accuracy: 0.9106
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 42s 600ms/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 0.7013 - val_loss: 2.1072
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.0016Test loss: 0.6391 - Test accuracy: 0.9094
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 604ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6970 - val_loss: 2.1346
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0012Test loss: 0.5784 - Test accuracy: 0.9106
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 603ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.7034 - val_loss: 1.9263
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 8.7914e-04Test loss: 0.6603 - Test accuracy: 0.9106
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 592ms/step - accuracy: 1.0000 - loss: 8.7453e-04 - val_accuracy: 0.7013 - val_loss: 2.2068
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 1.9026e-04Test loss: 0.6660 - Test accuracy: 0.9087
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 620ms/step - accuracy: 1.0000 - loss: 1.9020e-04 - val_accuracy: 0.6949 - val_loss: 2.2262
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 1.3835e-04Test loss: 0.6774 - Test accuracy: 0.9081
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 608ms/step - accuracy: 1.0000 - loss: 1.3808e-04 - val_accuracy: 0.6928 - val_loss: 2.2643
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 1.0593e-04Test loss: 0.6911 - Test accuracy: 0.9075
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 598ms/step - accuracy: 1.0000 - loss: 1.0598e-04 - val_accuracy: 0.6907 - val_loss: 2.3102
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 9.2845e-05Test loss: 0.6973 - Test accuracy: 0.9081
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 634ms/step - accuracy: 1.0000 - loss: 9.2808e-05 - val_accuracy: 0.6928 - val_loss: 2.3310
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 8.7283e-05Test loss: 0.7071 - Test accuracy: 0.9081
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 584ms/step - accuracy: 1.0000 - loss: 8.7196e-05 - val_accuracy: 0.6928 - val_loss: 2.3639
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 1.0000 - loss: 8.0677e-05Test loss: 0.7129 - Test accuracy: 0.9081
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 584ms/step - accuracy: 1.0000 - loss: 8.0479e-05 - val_accuracy: 0.6928 - val_loss: 2.3833
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 213ms/step - accuracy: 0.8873 - loss: 0.7276
# Final Test Loss: 0.7129229307174683
# Final Test Accuracy: 90.81%

# %% [markdown]
# # 3 Block

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Set the path to your balanced dataset
balanced_dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Set the image dimensions and other parameters
input_shape = (224, 224, 3)
batch_size = 32
num_classes = 3
epochs = 20

# Create the data generator for training and validation without data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test generator
test_generator = test_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Calculate the class weights to handle data imbalance
class_weights_balanced = dict(zip(range(num_classes), ((len(train_generator_balanced.classes) / (num_classes * np.bincount(train_generator_balanced.classes))).tolist())))

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc
ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.7203 - val_loss: 2.1239
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9956 - loss: 0.0092Test loss: 0.6321 - Test accuracy: 0.9144
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 602ms/step - accuracy: 0.9956 - loss: 0.0093 - val_accuracy: 0.7203 - val_loss: 2.0950
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9961 - loss: 0.0063Test loss: 0.7608 - Test accuracy: 0.9157
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 591ms/step - accuracy: 0.9962 - loss: 0.0062 - val_accuracy: 0.7225 - val_loss: 2.5370
# Epoch 18/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9955 - loss: 0.0042Test loss: 0.7758 - Test accuracy: 0.9151
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 592ms/step - accuracy: 0.9956 - loss: 0.0042 - val_accuracy: 0.7203 - val_loss: 2.5792
# Epoch 19/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9986 - loss: 0.0046Test loss: 0.8062 - Test accuracy: 0.9208
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 609ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.7373 - val_loss: 2.6909
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9973 - loss: 0.0061Test loss: 0.8080 - Test accuracy: 0.9163
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 600ms/step - accuracy: 0.9973 - loss: 0.0061 - val_accuracy: 0.7225 - val_loss: 2.6971
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.8990 - loss: 0.8090
# Final Test Loss: 0.8080031871795654
# Final Test Accuracy: 91.63%

# %% [markdown]
# # 4 Block

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Set the path to your balanced dataset
balanced_dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Set the image dimensions and other parameters
input_shape = (224, 224, 3)
batch_size = 32
num_classes = 3
epochs = 20

# Create the data generator for training and validation without data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test generator
test_generator = test_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Calculate the class weights to handle data imbalance
class_weights_balanced = dict(zip(range(num_classes), ((len(train_generator_balanced.classes) / (num_classes * np.bincount(train_generator_balanced.classes))).tolist())))

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc = model.evaluate(test_generator, verbose=0)
        test_loss.append(loss)
        test_accuracy.append(acc)
        print(f'Test loss: {loss:.4f} - Test accuracy: {acc:.4f}')

# Train the model with the custom callback
history = model.fit(train_generator_balanced, 
                    epochs=epochs, 
                    validation_data=validation_generator_balanced, 
                    class_weight=class_weights_balanced,
                    callbacks=[TestCallback()])

# Final evaluation on the test set
loss, accuracy = model.evaluate(test_generator)
print('Final Test Loss:', loss)
print(f'Final Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Found 1106 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 1578 images belonging to 3 classes.
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.4185 - loss: 1.2425Test loss: 0.7968 - Test accuracy: 0.6388
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 30s 731ms/step - accuracy: 0.4201 - loss: 1.2363 - val_accuracy: 0.6292 - val_loss: 0.8260
# Epoch 2/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.6502 - loss: 0.7537Test loss: 0.6341 - Test accuracy: 0.7237
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 591ms/step - accuracy: 0.6495 - loss: 0.7510 - val_accuracy: 0.6822 - val_loss: 0.7248
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7211 - loss: 0.5911Test loss: 0.6435 - Test accuracy: 0.6946
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 602ms/step - accuracy: 0.7209 - loss: 0.5908 - val_accuracy: 0.6250 - val_loss: 0.8197
# Epoch 4/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7763 - loss: 0.5075Test loss: 0.4727 - Test accuracy: 0.8124
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 583ms/step - accuracy: 0.7759 - loss: 0.5076 - val_accuracy: 0.7140 - val_loss: 0.6916
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8078 - loss: 0.4065Test loss: 0.4189 - Test accuracy: 0.8409
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 590ms/step - accuracy: 0.8080 - loss: 0.4055 - val_accuracy: 0.7521 - val_loss: 0.7586
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8753 - loss: 0.2843Test loss: 0.5000 - Test accuracy: 0.8359
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 609ms/step - accuracy: 0.8752 - loss: 0.2844 - val_accuracy: 0.7182 - val_loss: 1.1225
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.
# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc = model.evaluate(test_generator, verbose=0)
        test_loss.append(loss)
        test_accuracy.append(acc)
        print(f'Test loss: {loss:.4f} - Test accuracy: {acc:.4f}')

# Train the model with the custom callback
history = model.fit(train_generator_balanced, 
                    epochs=epochs, 
                    validation_data=validation_generator_balanced, 
                    class_weight=class_weights_balanced,
                    callbacks=[TestCallback()])

# Final evaluation on the test set
loss, accuracy = model.evaluate(test_generator)
print('Final Test Loss:', loss)
print(f'Final Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Found 1106 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 1578 images belonging to 3 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731422959.556991     118 service.cc:145] XLA service 0x7f9c040037f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731422959.557061     118 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1731422959.557066     118 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  1/35 ━━━━━━━━━━━━━━━━━━━━ 6:04 11s/step - accuracy: 0.2188 - loss: 1.1809
# I0000 00:00:1731422965.548180     118 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.4743 - loss: 1.0454Test loss: 0.9074 - Test accuracy: 0.4892
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 979ms/step - accuracy: 0.4770 - loss: 1.0417 - val_accuracy: 0.4767 - val_loss: 0.8883
# Epoch 2/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5211 - loss: 0.8756Test loss: 0.7494 - Test accuracy: 0.6635
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 569ms/step - accuracy: 0.5219 - loss: 0.8724 - val_accuracy: 0.6547 - val_loss: 0.7660
# Epoch 3/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6666 - loss: 0.6807Test loss: 0.6153 - Test accuracy: 0.6939
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 547ms/step - accuracy: 0.6665 - loss: 0.6797 - val_accuracy: 0.6186 - val_loss: 0.7669
# Epoch 4/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7221 - loss: 0.5507Test loss: 0.5254 - Test accuracy: 0.7731
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 567ms/step - accuracy: 0.7229 - loss: 0.5500 - val_accuracy: 0.7034 - val_loss: 0.7203
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7943 - loss: 0.4522Test loss: 0.5135 - Test accuracy: 0.7668
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 556ms/step - accuracy: 0.7942 - loss: 0.4521 - val_accuracy: 0.6568 - val_loss: 0.7492
# Epoch 6/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8187 - loss: 0.3763Test loss: 0.5377 - Test accuracy: 0.7763
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 543ms/step - accuracy: 0.8184 - loss: 0.3768 - val_accuracy: 0.6631 - val_loss: 0.8771
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8396 - loss: 0.3524Test loss: 0.5279 - Test accuracy: 0.8207
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 569ms/step - accuracy: 0.8399 - loss: 0.3514 - val_accuracy: 0.7203 - val_loss: 1.0536
# Epoch 8/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8659 - loss: 0.2729Test loss: 0.5637 - Test accuracy: 0.8232
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 537ms/step - accuracy: 0.8658 - loss: 0.2743 - val_accuracy: 0.6822 - val_loss: 1.2087
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8874 - loss: 0.2455Test loss: 0.4587 - Test accuracy: 0.8568
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 567ms/step - accuracy: 0.8873 - loss: 0.2464 - val_accuracy: 0.7500 - val_loss: 1.0098
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8890 - loss: 0.2172Test loss: 0.4933 - Test accuracy: 0.8359
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 546ms/step - accuracy: 0.8889 - loss: 0.2176 - val_accuracy: 0.7161 - val_loss: 1.0176
# Epoch 11/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9082 - loss: 0.1700Test loss: 0.7375 - Test accuracy: 0.8568
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 551ms/step - accuracy: 0.9090 - loss: 0.1696 - val_accuracy: 0.7161 - val_loss: 1.7691
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9021 - loss: 0.2696Test loss: 0.4741 - Test accuracy: 0.8783
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 558ms/step - accuracy: 0.9018 - loss: 0.2694 - val_accuracy: 0.7458 - val_loss: 1.1945
# Epoch 13/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9274 - loss: 0.1299Test loss: 0.6215 - Test accuracy: 0.9005
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 560ms/step - accuracy: 0.9278 - loss: 0.1296 - val_accuracy: 0.7479 - val_loss: 1.8533
# Epoch 14/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9339 - loss: 0.1727Test loss: 0.5777 - Test accuracy: 0.8992
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 549ms/step - accuracy: 0.9332 - loss: 0.1745 - val_accuracy: 0.7394 - val_loss: 1.7105
# Epoch 15/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9666 - loss: 0.0963Test loss: 0.5965 - Test accuracy: 0.9151
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 565ms/step - accuracy: 0.9664 - loss: 0.0962 - val_accuracy: 0.7585 - val_loss: 1.8388
# Epoch 16/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9704 - loss: 0.0690Test loss: 0.5911 - Test accuracy: 0.9252
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 21s 559ms/step - accuracy: 0.9703 - loss: 0.0691 - val_accuracy: 0.7691 - val_loss: 1.8999
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9895 - loss: 0.0348Test loss: 0.8286 - Test accuracy: 0.9189
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 542ms/step - accuracy: 0.9894 - loss: 0.0348 - val_accuracy: 0.7331 - val_loss: 2.7342
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9925 - loss: 0.0196Test loss: 0.7703 - Test accuracy: 0.9214
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 548ms/step - accuracy: 0.9924 - loss: 0.0198 - val_accuracy: 0.7521 - val_loss: 2.5132
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9948 - loss: 0.0214Test loss: 0.7217 - Test accuracy: 0.9214
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 545ms/step - accuracy: 0.9946 - loss: 0.0216 - val_accuracy: 0.7606 - val_loss: 2.3299
# Epoch 20/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9930 - loss: 0.0217Test loss: 0.7983 - Test accuracy: 0.9202
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 20s 550ms/step - accuracy: 0.9930 - loss: 0.0216 - val_accuracy: 0.7415 - val_loss: 2.6439
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 0.9025 - loss: 0.7600
# Final Test Loss: 0.7983227968215942
# Final Test Accuracy: 92.02%

# %% [markdown]
# # 6 Block

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Set the path to your balanced dataset
balanced_dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Set the image dimensions and other parameters
input_shape = (224, 224, 3)
batch_size = 32
num_classes = 3
epochs = 20

# Create the data generator for training and validation without data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test generator
test_generator = test_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Calculate the class weights to handle data imbalance
class_weights_balanced = dict(zip(range(num_classes), ((len(train_generator_balanced.classes) / (num_classes * np.bincount(train_generator_balanced.classes))).tolist())))

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc = model.evaluate(test_generator, verbose=0)
        test_loss.append(loss)
        test_accuracy.append(acc)
        print(f'Test loss: {loss:.4f} - Test accuracy: {acc:.4f}')

# Train the model with the custom callback
history = model.fit(train_generator_balanced, 
                    epochs=epochs, 
                    validation_data=validation_generator_balanced, 
                    class_weight=class_weights_balanced,
                    callbacks=[TestCallback()])

# Final evaluation on the test set
loss, accuracy = model.evaluate(test_generator)
print('Final Test Loss:', loss)
print(f'Final Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Found 1106 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 1578 images belonging to 3 classes.
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.4458 - loss: 1.0129Test loss: 0.8339 - Test accuracy: 0.6033
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 30s 709ms/step - accuracy: 0.4473 - loss: 1.0115 - val_accuracy: 0.5953 - val_loss: 0.8356
# Epoch 2/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.6017 - loss: 0.8656Test loss: 0.6913 - Test accuracy: 0.6705
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 590ms/step - accuracy: 0.6016 - loss: 0.8630 - val_accuracy: 0.6589 - val_loss: 0.7399
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6698 - loss: 0.6551Test loss: 0.6823 - Test accuracy: 0.6698
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 594ms/step - accuracy: 0
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 650ms/step - accuracy: 0.9625 - loss: 0.0854 - val_accuracy: 0.7797 - val_loss: 1.4015
# Epoch 20/20
# 34/35 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9424 - loss: 0.1205Test loss: 0.4596 - Test accuracy: 0.9170
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 581ms/step - accuracy: 0.9430 - loss: 0.1195 - val_accuracy: 0.7775 - val_loss: 1.3631
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 212ms/step - accuracy: 0.9126 - loss: 0.3857
# Final Test Loss: 0.4595556855201721
# Final Test Accuracy: 91.70%

# %% [markdown]
# # 7 Block

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Set the path to your balanced dataset
balanced_dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Set the image dimensions and other parameters
input_shape = (224, 224, 3)
batch_size = 32
num_classes = 3
epochs = 20

# Create the data generator for training and validation without data augmentation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator_balanced = train_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test generator
test_generator = test_datagen.flow_from_directory(
    balanced_dataset_path,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Calculate the class weights to handle data imbalance
class_weights_balanced = dict(zip(range(num_classes), ((len(train_generator_balanced.classes) / (num_classes * np.bincount(train_generator_balanced.classes))).tolist())))

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Create lists to hold the test loss and accuracy
test_loss = []
test_accuracy = []

# Custom callback to record test loss and accuracy after each epoch
class TestCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss, acc = model.evaluate(test_generator, verbose=0)
        test_loss.append(loss)
        test_accuracy.append(acc)
        print(f'Test loss: {loss:.4f} - Test accuracy: {acc:.4f}')

# Train the model with the custom callback
history = model.fit(train_generator_balanced, 
                    epochs=epochs, 
                    validation_data=validation_generator_balanced, 
                    class_weight=class_weights_balanced,
                    callbacks=[TestCallback()])

# Final evaluation on the test set
loss, accuracy = model.evaluate(test_generator)
print('Final Test Loss:', loss)
print(f'Final Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# Found 1106 images belonging to 3 classes.
# Found 472 images belonging to 3 classes.
# Found 1578 images belonging to 3 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 70
#      67 model.add(Conv2D(128, (3, 3), activation='relu'))
#      68 model.add(MaxPooling2D((2, 2)))
# ---> 70 model.add(Conv2D(128, (3, 3), activation='relu'))
#      71 model.add(MaxPooling2D((2, 2)))
#      73 model.add(Flatten())
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py:120, in Sequential.add(self, layer, rebuild)
#     118 self._layers.append(layer)
#     119 if rebuild:
# --> 120     self._maybe_rebuild()
#     121 else:
#     122     self.built = False
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py:139, in Sequential._maybe_rebuild(self)
#     137 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     138     input_shape = self._layers[0].batch_shape
# --> 139     self.build(input_shape)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/layers/layer.py:223, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     220 @wraps(original_build_method)
#     221 def build_wrapper(*args, **kwargs):
#     222     with obj._open_name_scope():
# --> 223         original_build_method(*args, **kwargs)
#     224     # Record build config.
#     225     signature = inspect.signature(original_build_method)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py:183, in Sequential.build(self, input_shape)
#     181 for layer in self._layers[1:]:
#     182     try:
# --> 183         x = layer(x)
#     184     except NotImplementedError:
#     185         # Can happen if shape inference is not implemented.
#     186         # TODO: consider reverting inbound nodes on layers processed.
#     187         return
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/ops/operation_utils.py:221, in compute_conv_output_shape(input_shape, filters, kernel_size, strides, padding, data_format, dilation_rate)
#     219     for i in range(len(output_spatial_shape)):
#     220         if i not in none_dims and output_spatial_shape[i] < 0:
# --> 221             raise ValueError(
#     222                 "Computed output size would be negative. Received "
#     223                 f"`inputs shape={input_shape}`, "
#     224                 f"`kernel shape={kernel_shape}`, "
#     225                 f"`dilation_rate={dilation_rate}`."
#     226             )
#     227 elif padding == "same" or padding == "causal":
#     228     output_spatial_shape = np.floor((spatial_shape - 1) / strides) + 1
#
# ValueError: Computed output size would be negative. Received `inputs shape=(None, 1, 1, 128)`, `kernel shape=(3, 3, 128, 128)`, `dilation_rate=[1 1]`.
